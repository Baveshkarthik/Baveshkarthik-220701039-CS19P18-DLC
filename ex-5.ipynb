# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.metrics import r2_score
np.random.seed(0)
seq_length = 10
num_samples = 1000

X = np.random.randn(num_samples, seq_length, 1)

y = X.sum(axis=1) + 0.1 * np.random.randn(num_samples, 1)

split_ratio = 0.8
split_index = int(split_ratio * num_samples)

X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

model = Sequential()
model.add(SimpleRNN(units=50, activation='relu', input_shape=(seq_length, 1)))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

batch_size = 30
epochs = 50 # Reduced epochs for quick demonstration
history = model.fit(
X_train, y_train,
batch_size=batch_size,

epochs=epochs,
validation_split=0.2
)
test_loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}')

y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print(f'Test Accuracy (R^2): {r2:.4f}')

new_data = np.random.randn(5, seq_length, 1)
predictions = model.predict(new_data)
print("Predictions for new data:")
print(predictions)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 50)                2600
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 2,651
# Trainable params: 2,651
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 22/22 [==============================] - 12s 111ms/step - loss: 8.7742 - val_loss: 6.1406
# Epoch 2/50
# 22/22 [==============================] - 0s 17ms/step - loss: 4.2487 - val_loss: 1.8634
# Epoch 3/50
# 22/22 [==============================] - 0s 21ms/step - loss: 1.2003 - val_loss: 0.6171
# Epoch 4/50
# 22/22 [==============================] - 0s 21ms/step - loss: 0.4996 - val_loss: 0.3491
# Epoch 5/50
# 22/22 [==============================] - 1s 25ms/step - loss: 0.2312 - val_loss: 0.1979
# Epoch 6/50
# 22/22 [==============================] - 0s 21ms/step - loss: 0.1455 - val_loss: 0.1615
# Epoch 7/50
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0935 - val_loss: 0.0867
# Epoch 8/50
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0615 - val_loss: 0.0910
# Epoch 9/50
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0449 - val_loss: 0.0623
# Epoch 10/50
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0388 - val_loss: 0.0545
# Epoch 11/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0408 - val_loss: 0.0516
# Epoch 12/50
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0342 - val_loss: 0.0517
# Epoch 13/50
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0296 - val_loss: 0.0488
# Epoch 14/50
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0363 - val_loss: 0.0487
# Epoch 15/50
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0308 - val_loss: 0.0714
# Epoch 16/50
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0412 - val_loss: 0.0403
# Epoch 17/50
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0286 - val_loss: 0.0504
# Epoch 18/50
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0347 - val_loss: 0.0576
# Epoch 19/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0307 - val_loss: 0.0386
# Epoch 20/50
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0336 - val_loss: 0.0510
# Epoch 21/50
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0286 - val_loss: 0.0367
# Epoch 22/50
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0223 - val_loss: 0.0361
# Epoch 23/50
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0229 - val_loss: 0.0486
# Epoch 24/50
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0237 - val_loss: 0.0338
# Epoch 25/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0195 - val_loss: 0.0324
# Epoch 26/50
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0326 - val_loss: 0.0659
# Epoch 27/50
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0390 - val_loss: 0.0303
# Epoch 28/50
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0291 - val_loss: 0.0320
# Epoch 29/50
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0241 - val_loss: 0.0352
# Epoch 30/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0274 - val_loss: 0.0308
# Epoch 31/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0187 - val_loss: 0.0357
# Epoch 32/50
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0235 - val_loss: 0.0334
# Epoch 33/50
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0248 - val_loss: 0.0396
# Epoch 34/50
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0270 - val_loss: 0.0383
# Epoch 35/50
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0172 - val_loss: 0.0276
# Epoch 36/50
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0152 - val_loss: 0.0483
# Epoch 37/50
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0210 - val_loss: 0.0264
# Epoch 38/50
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0170 - val_loss: 0.0294
# Epoch 39/50
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0169 - val_loss: 0.0263
# Epoch 40/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0152 - val_loss: 0.0362
# Epoch 41/50
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0181 - val_loss: 0.0420
# Epoch 42/50
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0272 - val_loss: 0.0353
# Epoch 43/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0200 - val_loss: 0.0299
# Epoch 44/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0159 - val_loss: 0.0243
# Epoch 45/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0141 - val_loss: 0.0366
# Epoch 46/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0172 - val_loss: 0.0246
# Epoch 47/50
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0192 - val_loss: 0.0255
# Epoch 48/50
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0166 - val_loss: 0.0278
# Epoch 49/50
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0169 - val_loss: 0.0256
# Epoch 50/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0276 - val_loss: 0.0492
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0359
# Test Loss: 0.0359
# 7/7 [==============================] - 2s 6ms/step
# Test Accuracy (R^2): 0.9961
# 1/1 [==============================] - 0s 452ms/step
# Predictions for new data:
# [[ 1.7702199 ]
#  [ 0.19536504]
#  [-2.4214303 ]
#  [-0.74367523]
#  [-3.988674  ]]
